# %%
import csv

def replaceNaNs(f):
    AichiPrefectureLatAvg = 0
    AichiPrefectureLatCounter = 0
    AichiPrefectureLongAvg = 0
    AichiPrefectureLongCounter = 0
    
    AnhuiLatAvg = 0
    AnhuiLatCounter = 0
    AnhuiLongAvg = 0
    AnhuiLongCounter = 0
    
    BeijingLatAvg = 0
    BeijingLatCounter = 0
    BeijingLongAvg = 0
    BeijingLongCounter = 0
    
    GansuLatAvg = 0
    GansuLatCounter = 0
    GansuLongAvg = 0
    GansuLongCounter = 0
    
    GuangdongLatAvg = 0
    GuangdongLatCounter = 0
    GuangdongLongAvg = 0
    GuangdongLongCounter = 0
    
    GuangxiLatAvg = 0
    GuangxiLatCounter = 0
    GuangxiLongAvg = 0
    GuangxiLongCounter = 0
    
    GuizhouLatAvg = 0
    GuizhouLatCounter = 0
    GuizhouLongAvg = 0
    GuizhouLongCounter = 0
    
    hokkiadoLatAvg = 0
    hokkiadoLatCounter = 0
    hokkiadoLongAvg = 0
    hokkiadoLongCounter = 0
    
    HongKongLatAvg = 0
    HongKongLatCounter = 0
    HongKongLongAvg = 0
    HongKongLongCounter = 0
    
    with open(f) as csvfile:
        reader = csv.reader(csvfile)
        columns = next(reader)
        for y in reader:
            if y[6] != 'NaN':
                if y[4] == 'Aichi Prefecture':
                    AichiPrefectureLatAvg += float(y[6])
                    AichiPrefectureLatCounter += 1
                elif y[4] == 'Anhui':
                    AnhuiLatAvg += float(y[6])
                    AnhuiLatCounter += 1
                elif y[4] == 'Beijing':
                    BeijingLatAvg += float(y[6])
                    BeijingLatCounter += 1
                elif y[4] == 'Gansu':
                    GansuLatAvg += float(y[6])
                    GansuLatCounter += 1
                elif y[4] == 'Guangdong':
                    GuangdongLatAvg += float(y[6])
                    GuangdongLatCounter += 1
                elif y[4] == 'Guangxi':
                    GuangxiLatAvg += float(y[6])
                    GuangxiLatCounter += 1
                elif y[4] == 'Guizhou':
                    GuizhouLatAvg += float(y[6])
                    GuizhouLatCounter += 1
                elif y[4] == 'Hokkaido':
                    hokkiadoLatAvg +=float(y[6])
                    hokkiadoLatCounter += 1
                elif y[4] == 'Hong Kong':
                    HongKongLatAvg += float(y[6])
                    HongKongLatCounter += 1
                else:
                        print("oops")
            if y[7] != 'NaN':
                if y[4] == 'Aichi Prefecture':
                    AichiPrefectureLongAvg += float(y[7])
                    AichiPrefectureLongCounter += 1
                elif y[4] == 'Anhui':
                    AnhuiLongAvg += float(y[7])
                    AnhuiLongCounter += 1
                elif y[4] == 'Beijing':
                    BeijingLongAvg += float(y[7])
                    BeijingLongCounter += 1
                elif y[4] == 'Gansu':
                    GansuLongAvg += float(y[7])
                    GansuLongCounter += 1
                elif y[4] == 'Guangdong':
                    GuangdongLongAvg += float(y[7])
                    GuangdongLongCounter += 1
                elif y[4] == 'Guangxi':
                    GuangxiLongAvg += float(y[7])
                    GuangxiLongCounter += 1
                elif y[4] == 'Guizhou':
                    GuizhouLongAvg += float(y[7])
                    GuizhouLongCounter += 1
                elif y[4] == 'Hokkaido':
                    hokkiadoLongAvg +=float(y[7])
                    hokkiadoLongCounter += 1
                elif y[4] == 'Hong Kong':
                    HongKongLongAvg += float(y[7])
                    HongKongLongCounter += 1
                else:
                        print("oops")
                    
        AichiPrefectureLatAvg /= AichiPrefectureLatCounter
        AichiPrefectureLongAvg /= AichiPrefectureLongCounter
        AnhuiLatAvg /= AnhuiLatCounter
        AnhuiLongAvg /= AnhuiLongCounter
        BeijingLatAvg /= BeijingLatCounter
        BeijingLongAvg /=BeijingLongCounter
        GansuLatAvg /= GansuLatCounter
        GansuLongAvg /= GansuLongCounter
        GuangdongLatAvg /= GuangdongLatCounter
        GuangdongLongAvg /= GuangdongLongCounter
        GuangxiLatAvg /= GuangxiLatCounter
        GuangxiLongAvg /= GuangxiLongCounter
        GuizhouLatAvg /= GuizhouLatCounter
        GuizhouLongAvg /= GuizhouLongCounter
        hokkiadoLatAvg /= hokkiadoLatCounter
        hokkiadoLongAvg /= hokkiadoLongCounter
        HongKongLatAvg /= HongKongLatCounter
        HongKongLongAvg /= HongKongLongCounter
        
    AichiCounter = dict()
    AnhuiCounter = dict()
    BeijingCounter = dict()
    GansuCounter = dict()
    GuangdongCounter = dict()
    GuangxiCounter = dict()
    GuizhouCounter = dict()
    HokkiadoCounter = dict()
    HongKongCounter = dict()
    with open(f) as csvfile:
        reader = csv.reader(csvfile)
        columns = next(reader)
        for s in reader:
            if s[4] == 'Aichi Prefecture':
                symptom = s[11]
                if symptom != "NaN":
                    if "; " in symptom:
                        symptom = symptom.split("; ")
                    else:
                        symptom = symptom.split(";")
                    for i in symptom:
                        if i in AichiCounter:
                            AichiCounter[i] += 1
                        else:
                            AichiCounter[i] = 1
                        print(AichiCounter)
            elif s[4] == 'Anhui':
                symptom = s[11]
                if symptom != "NaN":
                    if "; " in symptom:
                        symptom = symptom.split("; ")
                    else:
                        symptom = symptom.split(";")
                    for i in symptom:
                        if i in AnhuiCounter:
                            AnhuiCounter[i] += 1
                        else:
                            AnhuiCounter[i] = 1
                        print(AnhuiCounter)
            elif s[4] == 'Beijing':
                symptom = s[11]
                if symptom != "NaN":
                    if "; " in symptom:
                        symptom = symptom.split("; ")
                    else:
                        symptom = symptom.split(";")
                    for i in symptom:
                        if i in BeijingCounter:
                            BeijingCounter[i] += 1
                        else:
                            BeijingCounter[i] = 1
                        print(BeijingCounter)
            elif s[4] == 'Gansu':
                symptom = s[11]
                if symptom != "NaN":
                    if "; " in symptom:
                        symptom = symptom.split("; ")
                    else:
                        symptom = symptom.split(";")
                    for i in symptom:
                        if i in GansuCounter:
                            GansuCounter[i] += 1
                        else:
                            GansuCounter[i] = 1
                        print(GansuCounter)

            elif s[4] == 'Guangdong':
                symptom = s[11]
                if symptom != "NaN":
                    if "; " in symptom:
                        symptom = symptom.split("; ")
                    else:
                        symptom = symptom.split(";")
                    for i in symptom:
                        if i in GuangdongCounter:
                            GuangdongCounter[i] += 1
                        else:
                            GuangdongCounter[i] = 1
                        print(GuangdongCounter)

            elif s[4] == 'Guangxi':
                symptom = s[11]
                if symptom != "NaN":
                    if "; " in symptom:
                        symptom = symptom.split("; ")
                    else:
                        symptom = symptom.split(";")
                    for i in symptom:
                        if i in GuangxiCounter:
                            GuangxiCounter[i] += 1
                        else:
                            GuangxiCounter[i] = 1
                        print(GuangxiCounter)

            elif s[4] == 'Guizhou':
                symptom = s[11]
                if symptom != "NaN":
                    if "; " in symptom:
                        symptom = symptom.split("; ")
                    else:
                        symptom = symptom.split(";")
                    for i in symptom:
                        if i in GuizhouCounter:
                            GuizhouCounter[i] += 1
                        else:
                            GuizhouCounter[i] = 1
                        print(GuizhouCounter)

            elif s[4] == 'Hokkaido':
                symptom = s[11]
                if symptom != "NaN":
                    if "; " in symptom:
                        symptom = symptom.split("; ")
                    else:
                        symptom = symptom.split(";")
                    for i in symptom:
                        if i in HokkiadoCounter:
                            HokkiadoCounter[i] += 1
                        else:
                            HokkiadoCounter[i] = 1
                        print(HokkiadoCounter)
            elif s[4] == 'Hong Kong':
                symptom = s[11]
                if symptom != "NaN":
                    if "; " in symptom:
                        symptom = symptom.split("; ")
                    else:
                        symptom = symptom.split(";")
                    for i in symptom:
                        if i in HongKongCounter:
                            HongKongCounter[i] += 1
                        else:
                            HongKongCounter[i] = 1
                        print(HongKongCounter)
 
            else:
                print("oops")
    
    with open(f) as csvfile:
        reader = csv.reader(csvfile)
        with open('covidResult.csv','w',newline='') as csvout:
            writer = csv.writer(csvout)
            columns = next(reader)  
            writer.writerow(columns)
            for x in reader:
                if "-" in x[1]:
                    l = x[1].split("-")
                    x[1] = str(int((int(l[0]) + int(l[1])) /2 + 0.5))
                l = x[8].split(".")
                x[8] = l[1] + "." + l[0] + "." + l[2]
                l = x[9].split(".")
                x[9] = l[1] + "." + l[0] + "." + l[2]
                l = x[10].split(".")
                x[10] = l[1] + "." + l[0] + "." + l[2]
                
                if x[6] == 'NaN':
                    if x[4] == 'Aichi Prefecture':
                        x[6] = round(AichiPrefectureLatAvg, 2)
                    elif x[4] == 'Anhui':
                        x[6] = round(AnhuiLatAvg, 2)
                    elif x[4] == 'Beijing':
                        x[6] = round(BeijingLatAvg, 2)
                    elif x[4] == 'Gansu':
                        x[6] = round(GansuLatAvg, 2)
                    elif x[4] == 'Guangdong':
                        x[6] = round(GuangdongLatAvg, 2)
                    elif x[4] == 'Guangxi':
                        x[6] = round(GuangxiLatAvg, 2)
                    elif x[4] == 'Guizhou':
                        x[6] = round(GuizhouLatAvg, 2)
                    elif x[4] == 'Hokkaido':
                        x[6] = round(hokkiadoLatAvg, 2)
                    elif x[4] == 'Hong Kong':
                        x[6] = round(HongKongLatAvg, 2)

                if x[7] == 'NaN':
                    if x[4] == 'Aichi Prefecture':
                        x[7] = round(AichiPrefectureLongAvg, 2)
                    elif x[4] == 'Anhui':
                        x[7] = round(AnhuiLongAvg, 2)
                    elif x[4] == 'Beijing':
                        x[7] = round(BeijingLongAvg, 2)
                    elif x[4] == 'Gansu':
                        x[7] = round(GansuLongAvg, 2)
                    elif x[4] == 'Guangdong':
                        x[7] = round(GuangdongLongAvg, 2)
                    elif x[4] == 'Guangxi':
                        x[7] = round(GuangxiLongAvg, 2)
                    elif x[4] == 'Guizhou':
                        x[7] = round(GuizhouLongAvg, 2)
                    elif x[4] == 'Hokkaido':
                        x[7] = round(hokkiadoLongAvg, 2)
                    elif x[4] == 'Hong Kong':
                        x[7] = round(HongKongLongAvg, 2)

                if x[3] == 'NaN':
                    if x[4] == 'Aichi Prefecture':
                        x[3] = 'Nagoya City'
                    elif x[4] == 'Anhui':
                        x[3] = 'Bozhou City'
                    elif x[4] == 'Beijing':
                        x[3] = 'Haidian District'
                    elif x[4] == 'Gansu':
                        x[3] = 'Chengguan District Lanzhou City'
                    elif x[4] == 'Guangdong':
                        x[3] = 'Shenzhen City'
                    elif x[4] == 'Guangxi':
                        x[3] = 'Fangchenggang City'
                    elif x[4] == 'Guizhou':
                        x[3] = 'Tongren City'
                    elif x[4] == 'Hokkaido':
                        x[3] = 'Nakafurano'
                    elif x[4] == 'Hong Kong':
                        x[3] = 'Hong Kong'

                if x[11] == 'NaN':
                    if x[4] == 'Aichi Prefecture':
                        x[11] = 'fever'
                    elif x[4] == 'Anhui':
                        x[11] = 'fever'
                    elif x[4] == 'Beijing':
                        x[11] = 'fever'
                    elif x[4] == 'Gansu':
                        x[11] = 'cough; fever'
                    elif x[4] == 'Guangdong':
                        x[11] = 'anhelation; cough; fever; pleural effusion; weaknessy'
                    elif x[4] == 'Guangxi':
                        x[11] = 'cough; fever'
                    elif x[4] == 'Guizhou':
                        x[11] = 'discomfort'
                    elif x[4] == 'Hokkaido':
                        x[11] = 'fever 37.7 C'
                    elif x[4] == 'Hong Kong':
                        x[11] = 'fever'
                writer.writerow(x)
def main():
    replaceNaNs("covidTrain.csv")

if __name__ == "__main__":
    main()
# Out:
# {'fever': 1}
# {'fever': 2}
# {'fever': 3}
# {'fever': 4}
# {'fever': 4, 'headache': 1}
# {'fever': 5, 'headache': 1}
# {'fever': 1}
# {'fever': 2}
# {'fever': 3}
# {'fever': 4}
# {'fever': 5}
# {'fever': 6}
# {'fever': 6, 'pharyngalgia': 1}
# {'fever': 7, 'pharyngalgia': 1}
# {'fever': 7, 'pharyngalgia': 1, 'cough': 1}
# {'fever': 8, 'pharyngalgia': 1, 'cough': 1}
# {'fever': 9, 'pharyngalgia': 1, 'cough': 1}
# {'fever': 9, 'pharyngalgia': 1, 'cough': 1, 'sore throat': 1}
# {'fever': 10, 'pharyngalgia': 1, 'cough': 1, 'sore throat': 1}
# {'fever': 11, 'pharyngalgia': 1, 'cough': 1, 'sore throat': 1}
# {'fever': 12, 'pharyngalgia': 1, 'cough': 1, 'sore throat': 1}
# {'fever': 13, 'pharyngalgia': 1, 'cough': 1, 'sore throat': 1}
# {'fever': 14, 'pharyngalgia': 1, 'cough': 1, 'sore throat': 1}
# {'fever': 14, 'pharyngalgia': 1, 'cough': 2, 'sore throat': 1}
# {'fever': 15, 'pharyngalgia': 1, 'cough': 2, 'sore throat': 1}
# {'fever': 15, 'pharyngalgia': 1, 'cough': 2, 'sore throat': 1, 'physical discomfort': 1}
# {'fever': 15, 'pharyngalgia': 1, 'cough': 3, 'sore throat': 1, 'physical discomfort': 1}
# {'fever': 16, 'pharyngalgia': 1, 'cough': 3, 'sore throat': 1, 'physical discomfort': 1}
# {'fever': 16, 'pharyngalgia': 1, 'cough': 3, 'sore throat': 1, 'physical discomfort': 1, 'chills': 1}
# {'fever': 16, 'pharyngalgia': 1, 'cough': 3, 'sore throat': 1, 'physical discomfort': 1, 'chills': 1, 'headache': 1}
# {'fever': 17, 'pharyngalgia': 1, 'cough': 3, 'sore throat': 1, 'physical discomfort': 1, 'chills': 1, 'headache': 1}
# {'fever': 18, 'pharyngalgia': 1, 'cough': 3, 'sore throat': 1, 'physical discomfort': 1, 'chills': 1, 'headache': 1}
# {'fever': 18, 'pharyngalgia': 1, 'cough': 3, 'sore throat': 1, 'physical discomfort': 1, 'chills': 1, 'headache': 1, 'pharyngeal discomfort': 1}
# {'fever': 18, 'pharyngalgia': 1, 'cough': 3, 'sore throat': 1, 'physical discomfort': 1, 'chills': 1, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1}
# {'fever': 19, 'pharyngalgia': 1, 'cough': 3, 'sore throat': 1, 'physical discomfort': 1, 'chills': 1, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1}
# {'fever': 20, 'pharyngalgia': 1, 'cough': 3, 'sore throat': 1, 'physical discomfort': 1, 'chills': 1, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1}
# {'fever': 21, 'pharyngalgia': 1, 'cough': 3, 'sore throat': 1, 'physical discomfort': 1, 'chills': 1, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1}
# {'fever': 21, 'pharyngalgia': 1, 'cough': 3, 'sore throat': 1, 'physical discomfort': 1, 'chills': 1, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1, 'joint pain': 1}
# {'fever': 21, 'pharyngalgia': 1, 'cough': 3, 'sore throat': 1, 'physical discomfort': 1, 'chills': 1, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1, 'joint pain': 1, 'muscle soreness': 1}
# {'fever': 22, 'pharyngalgia': 1, 'cough': 3, 'sore throat': 1, 'physical discomfort': 1, 'chills': 1, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1, 'joint pain': 1, 'muscle soreness': 1}
# {'fever': 22, 'pharyngalgia': 1, 'cough': 3, 'sore throat': 1, 'physical discomfort': 1, 'chills': 2, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1, 'joint pain': 1, 'muscle soreness': 1}
# {'fever': 23, 'pharyngalgia': 1, 'cough': 3, 'sore throat': 1, 'physical discomfort': 1, 'chills': 2, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1, 'joint pain': 1, 'muscle soreness': 1}
# {'fever': 23, 'pharyngalgia': 1, 'cough': 4, 'sore throat': 1, 'physical discomfort': 1, 'chills': 2, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1, 'joint pain': 1, 'muscle soreness': 1}
# {'fever': 24, 'pharyngalgia': 1, 'cough': 4, 'sore throat': 1, 'physical discomfort': 1, 'chills': 2, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1, 'joint pain': 1, 'muscle soreness': 1}
# {'fever': 24, 'pharyngalgia': 1, 'cough': 4, 'sore throat': 1, 'physical discomfort': 1, 'chills': 2, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1, 'joint pain': 1, 'muscle soreness': 1, 'chest pain': 1}
# {'fever': 24, 'pharyngalgia': 1, 'cough': 4, 'sore throat': 1, 'physical discomfort': 1, 'chills': 2, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1, 'joint pain': 1, 'muscle soreness': 1, 'chest pain': 1, 'nasal congestion': 1}
# {'fever': 24, 'pharyngalgia': 1, 'cough': 5, 'sore throat': 1, 'physical discomfort': 1, 'chills': 2, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1, 'joint pain': 1, 'muscle soreness': 1, 'chest pain': 1, 'nasal congestion': 1}
# {'fever': 24, 'pharyngalgia': 1, 'cough': 5, 'sore throat': 1, 'physical discomfort': 1, 'chills': 2, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1, 'joint pain': 1, 'muscle soreness': 2, 'chest pain': 1, 'nasal congestion': 1}
# {'fever': 24, 'pharyngalgia': 1, 'cough': 5, 'sore throat': 1, 'physical discomfort': 1, 'chills': 2, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1, 'joint pain': 1, 'muscle soreness': 2, 'chest pain': 1, 'nasal congestion': 1, 'sweating': 1}
# {'fever': 25, 'pharyngalgia': 1, 'cough': 5, 'sore throat': 1, 'physical discomfort': 1, 'chills': 2, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1, 'joint pain': 1, 'muscle soreness': 2, 'chest pain': 1, 'nasal congestion': 1, 'sweating': 1}
# {'fever': 25, 'pharyngalgia': 1, 'cough': 5, 'sore throat': 1, 'physical discomfort': 1, 'chills': 2, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1, 'joint pain': 1, 'muscle soreness': 2, 'chest pain': 1, 'nasal congestion': 1, 'sweating': 1, 'dry cough': 1}
# {'fever': 26, 'pharyngalgia': 1, 'cough': 5, 'sore throat': 1, 'physical discomfort': 1, 'chills': 2, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1, 'joint pain': 1, 'muscle soreness': 2, 'chest pain': 1, 'nasal congestion': 1, 'sweating': 1, 'dry cough': 1}
# {'fever': 26, 'pharyngalgia': 1, 'cough': 6, 'sore throat': 1, 'physical discomfort': 1, 'chills': 2, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1, 'joint pain': 1, 'muscle soreness': 2, 'chest pain': 1, 'nasal congestion': 1, 'sweating': 1, 'dry cough': 1}
# {'fever': 27, 'pharyngalgia': 1, 'cough': 6, 'sore throat': 1, 'physical discomfort': 1, 'chills': 2, 'headache': 1, 'pharyngeal discomfort': 1, 'chest tightness': 1, 'joint pain': 1, 'muscle soreness': 2, 'chest pain': 1, 'nasal congestion': 1, 'sweating': 1, 'dry cough': 1}
# {'respiratory symptoms': 1}
# {'respiratory symptoms': 1, 'fever': 1}
# {'respiratory symptoms': 1, 'fever': 2}
# {'respiratory symptoms': 2, 'fever': 2}
# {'respiratory symptoms': 2, 'fever': 3}
# {'respiratory symptoms': 3, 'fever': 3}
# {'respiratory symptoms': 3, 'fever': 4}
# {'respiratory symptoms': 3, 'fever': 5}
# {'respiratory symptoms': 3, 'fever': 6}
# {'discomfort': 1}
# {'discomfort': 1, 'fever': 1}
# {'discomfort': 1, 'fever': 1, 'cough': 1}
# {'discomfort': 1, 'fever': 2, 'cough': 1}
# {'discomfort': 1, 'fever': 2, 'cough': 1, 'headache': 1}
# {'discomfort': 1, 'fever': 2, 'cough': 1, 'headache': 1, 'muscular soreness': 1}
# {'discomfort': 1, 'fever': 2, 'cough': 1, 'headache': 1, 'muscular soreness': 1, 'weak': 1}
# {'discomfort': 1, 'fever': 3, 'cough': 1, 'headache': 1, 'muscular soreness': 1, 'weak': 1}
# {'discomfort': 1, 'fever': 3, 'cough': 2, 'headache': 1, 'muscular soreness': 1, 'weak': 1}
# {'discomfort': 1, 'fever': 4, 'cough': 2, 'headache': 1, 'muscular soreness': 1, 'weak': 1}
# {'discomfort': 1, 'fever': 4, 'cough': 2, 'headache': 1, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1}
# {'discomfort': 1, 'fever': 4, 'cough': 2, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1}
# {'discomfort': 1, 'fever': 4, 'cough': 2, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1}
# {'discomfort': 1, 'fever': 4, 'cough': 2, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1}
# {'discomfort': 1, 'fever': 4, 'cough': 2, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1}
# {'discomfort': 1, 'fever': 4, 'cough': 2, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 1}
# {'discomfort': 2, 'fever': 4, 'cough': 2, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 1}
# {'discomfort': 2, 'fever': 5, 'cough': 2, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 1}
# {'discomfort': 2, 'fever': 6, 'cough': 2, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 1}
# {'discomfort': 2, 'fever': 6, 'cough': 3, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 1}
# {'discomfort': 2, 'fever': 6, 'cough': 4, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 1}
# {'discomfort': 2, 'fever': 7, 'cough': 4, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 1}
# {'discomfort': 2, 'fever': 7, 'cough': 4, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 1, 'sputum': 1}
# {'discomfort': 2, 'fever': 7, 'cough': 5, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 1, 'sputum': 1}
# {'discomfort': 2, 'fever': 8, 'cough': 5, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 1, 'sputum': 1}
# {'discomfort': 2, 'fever': 8, 'cough': 6, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 1, 'sputum': 1}
# {'discomfort': 2, 'fever': 9, 'cough': 6, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 1, 'sputum': 1}
# {'discomfort': 2, 'fever': 9, 'cough': 7, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 1, 'sputum': 1}
# {'discomfort': 2, 'fever': 9, 'cough': 7, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 1, 'sputum': 2}
# {'discomfort': 2, 'fever': 10, 'cough': 7, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 1, 'sputum': 2}
# {'discomfort': 2, 'fever': 10, 'cough': 7, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 1, 'sputum': 2, 'chills': 1}
# {'discomfort': 2, 'fever': 10, 'cough': 7, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 2, 'sputum': 2, 'chills': 1}
# {'discomfort': 2, 'fever': 11, 'cough': 7, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 1, 'dry throat': 1, 'sore throat': 1, 'fatigue': 2, 'sputum': 2, 'chills': 1}
# {'discomfort': 2, 'fever': 11, 'cough': 7, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 1, 'sore throat': 1, 'fatigue': 2, 'sputum': 2, 'chills': 1}
# {'discomfort': 2, 'fever': 11, 'cough': 7, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 1, 'sore throat': 1, 'fatigue': 2, 'sputum': 2, 'chills': 1, 'throat discomfort': 1}
# {'discomfort': 2, 'fever': 11, 'cough': 7, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 1, 'sore throat': 1, 'fatigue': 2, 'sputum': 2, 'chills': 1, 'throat discomfort': 1, 'pharyngeal discomfort': 1}
# {'discomfort': 2, 'fever': 11, 'cough': 7, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 1, 'sore throat': 1, 'fatigue': 3, 'sputum': 2, 'chills': 1, 'throat discomfort': 1, 'pharyngeal discomfort': 1}
# {'discomfort': 2, 'fever': 11, 'cough': 7, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 2, 'sore throat': 1, 'fatigue': 3, 'sputum': 2, 'chills': 1, 'throat discomfort': 1, 'pharyngeal discomfort': 1}
# {'discomfort': 2, 'fever': 11, 'cough': 7, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 2, 'sore throat': 1, 'fatigue': 3, 'sputum': 2, 'chills': 1, 'throat discomfort': 1, 'pharyngeal discomfort': 1, 'dry cough': 1}
# {'discomfort': 2, 'fever': 11, 'cough': 8, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 2, 'sore throat': 1, 'fatigue': 3, 'sputum': 2, 'chills': 1, 'throat discomfort': 1, 'pharyngeal discomfort': 1, 'dry cough': 1}
# {'discomfort': 2, 'fever': 12, 'cough': 8, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 2, 'sore throat': 1, 'fatigue': 3, 'sputum': 2, 'chills': 1, 'throat discomfort': 1, 'pharyngeal discomfort': 1, 'dry cough': 1}
# {'discomfort': 2, 'fever': 13, 'cough': 8, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 2, 'sore throat': 1, 'fatigue': 3, 'sputum': 2, 'chills': 1, 'throat discomfort': 1, 'pharyngeal discomfort': 1, 'dry cough': 1}
# {'discomfort': 2, 'fever': 13, 'cough': 8, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 2, 'sore throat': 1, 'fatigue': 3, 'sputum': 2, 'chills': 1, 'throat discomfort': 1, 'pharyngeal discomfort': 1, 'dry cough': 1, 'diarrhea': 1}
# {'discomfort': 2, 'fever': 14, 'cough': 8, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 2, 'sore throat': 1, 'fatigue': 3, 'sputum': 2, 'chills': 1, 'throat discomfort': 1, 'pharyngeal discomfort': 1, 'dry cough': 1, 'diarrhea': 1}
# {'discomfort': 2, 'fever': 14, 'cough': 9, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 2, 'sore throat': 1, 'fatigue': 3, 'sputum': 2, 'chills': 1, 'throat discomfort': 1, 'pharyngeal discomfort': 1, 'dry cough': 1, 'diarrhea': 1}
# {'discomfort': 2, 'fever': 14, 'cough': 9, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 2, 'sore throat': 1, 'fatigue': 3, 'sputum': 3, 'chills': 1, 'throat discomfort': 1, 'pharyngeal discomfort': 1, 'dry cough': 1, 'diarrhea': 1}
# {'discomfort': 2, 'fever': 15, 'cough': 9, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 2, 'sore throat': 1, 'fatigue': 3, 'sputum': 3, 'chills': 1, 'throat discomfort': 1, 'pharyngeal discomfort': 1, 'dry cough': 1, 'diarrhea': 1}
# {'discomfort': 2, 'fever': 15, 'cough': 9, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 2, 'sore throat': 1, 'fatigue': 3, 'sputum': 3, 'chills': 1, 'throat discomfort': 1, 'pharyngeal discomfort': 1, 'dry cough': 2, 'diarrhea': 1}
# {'discomfort': 2, 'fever': 15, 'cough': 10, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 2, 'sore throat': 1, 'fatigue': 3, 'sputum': 3, 'chills': 1, 'throat discomfort': 1, 'pharyngeal discomfort': 1, 'dry cough': 2, 'diarrhea': 1}
# {'discomfort': 2, 'fever': 15, 'cough': 10, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 2, 'sore throat': 1, 'fatigue': 3, 'sputum': 3, 'chills': 1, 'throat discomfort': 1, 'pharyngeal discomfort': 1, 'dry cough': 2, 'diarrhea': 1, 'sore body': 1}
# {'discomfort': 2, 'fever': 15, 'cough': 10, 'headache': 2, 'muscular soreness': 1, 'weak': 1, 'runny nose': 1, 'dry mouth': 2, 'dry throat': 2, 'sore throat': 1, 'fatigue': 3, 'sputum': 3, 'chills': 1, 'throat discomfort': 1, 'pharyngeal discomfort': 1, 'dry cough': 2, 'diarrhea': 1, 'sore body': 1, 'cold': 1}
# {'cough': 1}
# {'cough': 1, 'fever': 1}
# {'cough': 1, 'fever': 1, 'weakness': 1}
# {'cough': 2, 'fever': 1, 'weakness': 1}
# {'cough': 2, 'fever': 1, 'weakness': 1, 'diarrhea': 1}
# {'cough': 2, 'fever': 2, 'weakness': 1, 'diarrhea': 1}
# {'cough': 2, 'fever': 2, 'weakness': 1, 'diarrhea': 1, 'nasal congestion': 1}
# {'cough': 2, 'fever': 2, 'weakness': 1, 'diarrhea': 1, 'nasal congestion': 1, 'pleuritic chest pain': 1}
# {'cough': 2, 'fever': 2, 'weakness': 1, 'diarrhea': 1, 'nasal congestion': 1, 'pleuritic chest pain': 1, 'sore throat': 1}
# {'cough': 2, 'fever': 2, 'weakness': 1, 'diarrhea': 1, 'nasal congestion': 1, 'pleuritic chest pain': 1, 'sore throat': 1, 'anhelation': 1}
# {'cough': 3, 'fever': 2, 'weakness': 1, 'diarrhea': 1, 'nasal congestion': 1, 'pleuritic chest pain': 1, 'sore throat': 1, 'anhelation': 1}
# {'cough': 3, 'fever': 3, 'weakness': 1, 'diarrhea': 1, 'nasal congestion': 1, 'pleuritic chest pain': 1, 'sore throat': 1, 'anhelation': 1}
# {'cough': 3, 'fever': 3, 'weakness': 1, 'diarrhea': 1, 'nasal congestion': 1, 'pleuritic chest pain': 1, 'sore throat': 1, 'anhelation': 1, 'pleural effusion': 1}
# {'cough': 3, 'fever': 3, 'weakness': 2, 'diarrhea': 1, 'nasal congestion': 1, 'pleuritic chest pain': 1, 'sore throat': 1, 'anhelation': 1, 'pleural effusion': 1}
# {'cough': 4, 'fever': 3, 'weakness': 2, 'diarrhea': 1, 'nasal congestion': 1, 'pleuritic chest pain': 1, 'sore throat': 1, 'anhelation': 1, 'pleural effusion': 1}
# {'cough': 4, 'fever': 3, 'weakness': 2, 'diarrhea': 2, 'nasal congestion': 1, 'pleuritic chest pain': 1, 'sore throat': 1, 'anhelation': 1, 'pleural effusion': 1}
# {'cough': 4, 'fever': 4, 'weakness': 2, 'diarrhea': 2, 'nasal congestion': 1, 'pleuritic chest pain': 1, 'sore throat': 1, 'anhelation': 1, 'pleural effusion': 1}
# {'cough': 4, 'fever': 4, 'weakness': 2, 'diarrhea': 2, 'nasal congestion': 1, 'pleuritic chest pain': 1, 'sore throat': 1, 'anhelation': 1, 'pleural effusion': 1, 'rhinorrhoea': 1}
# {'cough': 4, 'fever': 4, 'weakness': 2, 'diarrhea': 2, 'nasal congestion': 1, 'pleuritic chest pain': 1, 'sore throat': 1, 'anhelation': 1, 'pleural effusion': 1, 'rhinorrhoea': 1, 'sneezing': 1}
# {'cough': 5, 'fever': 4, 'weakness': 2, 'diarrhea': 2, 'nasal congestion': 1, 'pleuritic chest pain': 1, 'sore throat': 1, 'anhelation': 1, 'pleural effusion': 1, 'rhinorrhoea': 1, 'sneezing': 1}
# {'cough': 5, 'fever': 4, 'weakness': 2, 'diarrhea': 2, 'nasal congestion': 1, 'pleuritic chest pain': 1, 'sore throat': 1, 'anhelation': 1, 'pleural effusion': 1, 'rhinorrhoea': 1, 'sneezing': 1, 'dizziness': 1}
# {'fever': 1}
# {'fever': 1, 'dry cough': 1}
# {'fever': 1, 'dry cough': 1, 'fatigue': 1}
# {'fever': 2, 'dry cough': 1, 'fatigue': 1}
# {'fever': 2, 'dry cough': 1, 'fatigue': 2}
# {'fever': 2, 'dry cough': 1, 'fatigue': 2, 'chest tightness': 1}
# {'fever': 2, 'dry cough': 1, 'fatigue': 3, 'chest tightness': 1}
# {'fever': 3, 'dry cough': 1, 'fatigue': 3, 'chest tightness': 1}
# {'fever': 3, 'dry cough': 1, 'fatigue': 3, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1}
# {'fever': 4, 'dry cough': 1, 'fatigue': 3, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1}
# {'fever': 4, 'dry cough': 1, 'fatigue': 4, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1}
# {'fever': 4, 'dry cough': 1, 'fatigue': 4, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 1}
# {'fever': 5, 'dry cough': 1, 'fatigue': 4, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 1}
# {'fever': 5, 'dry cough': 1, 'fatigue': 5, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 1}
# {'fever': 6, 'dry cough': 1, 'fatigue': 5, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 1}
# {'fever': 6, 'dry cough': 1, 'fatigue': 5, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 2}
# {'fever': 7, 'dry cough': 1, 'fatigue': 5, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 2}
# {'fever': 7, 'dry cough': 1, 'fatigue': 5, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 2, 'fever;sore throat': 1}
# {'fever': 7, 'dry cough': 1, 'fatigue': 6, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 2, 'fever;sore throat': 1}
# {'fever': 7, 'dry cough': 1, 'fatigue': 6, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 2, 'fever;sore throat': 1, 'diarrhea': 1}
# {'fever': 8, 'dry cough': 1, 'fatigue': 6, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 2, 'fever;sore throat': 1, 'diarrhea': 1}
# {'fever': 9, 'dry cough': 1, 'fatigue': 6, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 2, 'fever;sore throat': 1, 'diarrhea': 1}
# {'fever': 10, 'dry cough': 1, 'fatigue': 6, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 2, 'fever;sore throat': 1, 'diarrhea': 1}
# {'fever': 10, 'dry cough': 1, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 2, 'fever;sore throat': 1, 'diarrhea': 1}
# {'fever': 10, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 2, 'fever;sore throat': 1, 'diarrhea': 1}
# {'fever': 11, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 2, 'fever;sore throat': 1, 'diarrhea': 1}
# {'fever': 11, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 2, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1}
# {'fever': 11, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 3, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1}
# {'fever': 12, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 3, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1}
# {'fever': 12, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 4, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1}
# {'fever': 13, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 4, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1}
# {'fever': 13, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 5, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1}
# {'fever': 14, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 5, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1}
# {'fever': 15, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 5, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1}
# {'fever': 15, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 5, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1, 'chest distress': 1}
# {'fever': 15, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 6, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1, 'chest distress': 1}
# {'fever': 15, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 6, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1, 'chest distress': 1, 'expectoration': 1}
# {'fever': 15, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 6, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1, 'chest distress': 1, 'expectoration': 1, 'muscular soreness': 1}
# {'fever': 15, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 7, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1, 'chest distress': 1, 'expectoration': 1, 'muscular soreness': 1}
# {'fever': 15, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 7, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1, 'chest distress': 1, 'expectoration': 1, 'muscular soreness': 1, 'headache': 1}
# {'fever': 16, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 7, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1, 'chest distress': 1, 'expectoration': 1, 'muscular soreness': 1, 'headache': 1}
# {'fever': 16, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 7, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1, 'chest distress': 1, 'expectoration': 1, 'muscular soreness': 1, 'headache': 1, 'sneeze': 1}
# {'fever': 17, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 7, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1, 'chest distress': 1, 'expectoration': 1, 'muscular soreness': 1, 'headache': 1, 'sneeze': 1}
# {'fever': 17, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 7, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1, 'chest distress': 1, 'expectoration': 1, 'muscular soreness': 1, 'headache': 1, 'sneeze': 1, 'discomfort': 1}
# {'fever': 18, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 7, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1, 'chest distress': 1, 'expectoration': 1, 'muscular soreness': 1, 'headache': 1, 'sneeze': 1, 'discomfort': 1}
# {'fever': 18, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 7, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1, 'chest distress': 1, 'expectoration': 1, 'muscular soreness': 1, 'headache': 1, 'sneeze': 1, 'discomfort': 1, 'nasal congestion': 1}
# {'fever': 18, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 7, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1, 'chest distress': 1, 'expectoration': 1, 'muscular soreness': 1, 'headache': 1, 'sneeze': 1, 'discomfort': 1, 'nasal congestion': 1, 'runny nose': 1}
# {'fever': 18, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 7, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1, 'chest distress': 1, 'expectoration': 1, 'muscular soreness': 1, 'headache': 1, 'sneeze': 1, 'discomfort': 1, 'nasal congestion': 1, 'runny nose': 1, 'sore throat': 1}
# {'fever': 18, 'dry cough': 2, 'fatigue': 7, 'chest tightness': 1, 'sore throat;fatigue;vomiting': 1, 'cough': 8, 'fever;sore throat': 1, 'diarrhea': 1, 'weak': 1, 'chest distress': 1, 'expectoration': 1, 'muscular soreness': 1, 'headache': 1, 'sneeze': 1, 'discomfort': 1, 'nasal congestion': 1, 'runny nose': 1, 'sore throat': 1}
# {'discomfort': 1}
# {'discomfort': 1, 'nausea': 1}
# {'discomfort': 1, 'nausea': 1, 'vomiting': 1}
# {'fever 37.7 C': 1}
# {'fever 37.7 C': 2}
# {'fever 37.7 C': 2, 'sore throat': 1}
# {'fever 37.7 C': 2, 'sore throat': 1, 'fever (38-39 C)': 1}
# {'fever 37.7 C': 2, 'sore throat': 1, 'fever (38-39 C)': 2}
# {'fever 37.7 C': 2, 'sore throat': 1, 'fever (38-39 C)': 2, 'malaise': 1}
# {'cough': 1}
# {'cough': 1, 'fever': 1}
# {'cough': 1, 'fever': 2}
# {'cough': 1, 'fever': 3}
# {'cough': 1, 'fever': 3, 'chills': 1}
# {'cough': 2, 'fever': 3, 'chills': 1}
# {'cough': 2, 'fever': 4, 'chills': 1}
# {'cough': 2, 'fever': 5, 'chills': 1}
# {'cough': 2, 'fever': 6, 'chills': 1}
# {'cough': 2, 'fever': 6, 'chills': 1, 'myalgia': 1}
# {'cough': 2, 'fever': 6, 'chills': 1, 'myalgia': 1, 'shortness of breath': 1}
# {'cough': 2, 'fever': 7, 'chills': 1, 'myalgia': 1, 'shortness of breath': 1}
# {'cough': 3, 'fever': 7, 'chills': 1, 'myalgia': 1, 'shortness of breath': 1}
# {'cough': 3, 'fever': 8, 'chills': 1, 'myalgia': 1, 'shortness of breath': 1}
# {'cough': 4, 'fever': 8, 'chills': 1, 'myalgia': 1, 'shortness of breath': 1}
# {'cough': 4, 'fever': 9, 'chills': 1, 'myalgia': 1, 'shortness of breath': 1}
# {'cough': 5, 'fever': 9, 'chills': 1, 'myalgia': 1, 'shortness of breath': 1}
# {'cough': 6, 'fever': 9, 'chills': 1, 'myalgia': 1, 'shortness of breath': 1}
# {'cough': 6, 'fever': 9, 'chills': 1, 'myalgia': 1, 'shortness of breath': 1, 'dyspnea': 1}
# {'cough': 7, 'fever': 9, 'chills': 1, 'myalgia': 1, 'shortness of breath': 1, 'dyspnea': 1}
# {'cough': 7, 'fever': 10, 'chills': 1, 'myalgia': 1, 'shortness of breath': 1, 'dyspnea': 1}
# {'cough': 8, 'fever': 10, 'chills': 1, 'myalgia': 1, 'shortness of breath': 1, 'dyspnea': 1}
# {'cough': 8, 'fever': 11, 'chills': 1, 'myalgia': 1, 'shortness of breath': 1, 'dyspnea': 1}
# {'cough': 9, 'fever': 11, 'chills': 1, 'myalgia': 1, 'shortness of breath': 1, 'dyspnea': 1}
